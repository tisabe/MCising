# %%
# %matplotlib inline

# %% [markdown]
# # Simple animation examples
#
#
# Two animations where the first is a random walk plot and
# the second is an image animation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation


def update_line(num, data, line):
    line.set_data(data[..., :num])
    return line,

# %%
fig1 = plt.figure()

# Fixing random state for reproducibility
np.random.seed(19680801)

data = np.random.rand(2, 25)
l, = plt.plot([], [], 'r-')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel('x')
plt.title('test')
line_ani = animation.FuncAnimation(fig1, update_line, 25, fargs=(data, l),
                                   interval=50, blit=True)
line_ani.save('lines.mp4')
# To save the animation, use the command: line_ani.save('lines.mp4')
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Users\Birkan\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2063             try:
# -> 2064                 format = EXTENSION[ext]
#    2065             except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3e64a636c525> in <module>
#      12 line_ani = animation.FuncAnimation(fig1, update_line, 25, fargs=(data, l),
#      13                                    interval=50, blit=True)
# ---> 14 line_ani.save('lines.mp4')
#      15 # To save the animation, use the command: line_ani.save('lines.mp4')
#
# D:\Users\Birkan\Anaconda3\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# D:\Users\Birkan\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# D:\Users\Birkan\Anaconda3\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# D:\Users\Birkan\Anaconda3\lib\site-packages\matplotlib\animation.py in finish(self)
#     575         self._frames[0].save(
#     576             self._outfile, save_all=True, append_images=self._frames[1:],
# --> 577             duration=int(1000 / self.fps), loop=0)
#     578
#     579
#
# D:\Users\Birkan\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2064                 format = EXTENSION[ext]
#    2065             except KeyError:
# -> 2066                 raise ValueError("unknown file extension: {}".format(ext))
#    2067
#    2068         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .mp4

# %%
fig = plt.figure()

x = np.arange(-49, 50)
y = np.arange(-49, 50).reshape(-1, 1)
base = np.hypot(x, y)
ims = []
for add in np.arange(100):
    ims.append((plt.pcolor(x, y, base + add, norm=plt.Normalize(0, 30)),))

im_ani = animation.ArtistAnimation(fig2, ims, interval=50, repeat_delay=3000,
                                   blit=True)
# To save this second animation with some metadata, use the following command:
im_ani.save('im2.mp4')

plt.show()
